# %%
#Mount GDrive and Import Github Repo

from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/JamyangRigsel/Assignment3
import os
os.chdir('/content/macro_project')

dataset_path = '/content/drive/MyDrive/macro_project/data/raw'

# %%
# !python ~m src.main
